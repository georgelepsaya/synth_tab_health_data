# %%
# from azure.ai.ml import command, Input, Output

# command_job = command(
#     code="./jobs",
#     command="python run_experiment.py ${{inputs.model_name}} ${{inputs.dataset_path}} ${{outputs.metrics_report}}",
#     environment="synthtabhealthdata:4",
#     inputs={
#         "model_name": "rtvae",
#         "dataset_path": Input(
#             type="uri_file",
#             path="azureml:heart_disease:1",
#         ),
#     },
#     outputs={
#         "metrics_report": Output(type="uri_file", mode="rw_mount"),
#     },
#     compute="cpu-cluster",
# )

# %%
from azure.ai.ml import load_job
from azure_ml_client import get_ml_client

ml_client = get_ml_client()
job_def = load_job(source="./jobs/evaluate_rtvae.yml")

job = ml_client.jobs.create_or_update(job_def)
print(f"Job {job.name} submitted: {job.studio_url}")
# Out:
# Overriding of current TracerProvider is not allowed
# Overriding of current LoggerProvider is not allowed
# Overriding of current MeterProvider is not allowed
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# File /workspaces/synth_tab_health_data/az_venv/lib/python3.12/site-packages/azure/ai/ml/entities/_util.py:192, in load_from_dict(schema, data, context, additional_message, **kwargs)
#     191 try:
# --> 192     return schema(context=context).load(data, **kwargs)
#     193 except ValidationError as e:
#
# File /workspaces/synth_tab_health_data/az_venv/lib/python3.12/site-packages/marshmallow/schema.py:792, in Schema.load(self, data, many, partial, unknown)
#     772 """Deserialize a data structure to an object defined by this Schema's fields.
#     773
#     774 :param data: The data to deserialize.
#    (...)    790     if invalid data are passed.
#     791 """
# --> 792 return self._do_load(
#     793     data, many=many, partial=partial, unknown=unknown, postprocess=True
#     794 )
#
# File /workspaces/synth_tab_health_data/az_venv/lib/python3.12/site-packages/marshmallow/schema.py:999, in Schema._do_load(self, data, many, partial, unknown, postprocess)
#     998     self.handle_error(exc, data, many=many, partial=partial)
# --> 999     raise exc
#    1001 return result
#
# ValidationError: {'code': [{'_schema': ["Can't find directory or file in resolved absolute path: /workspaces/synth_tab_health_data/jobs/experiments."]}, {'_schema': ['Not a valid URL.']}, {'_schema': ["In order to specify a git path, please provide the correct path prefixed with 'git+\n"]}, {'_schema': ["In order to specify an existing codes, please provide the correct registry path prefixed with 'azureml://':\n"]}, {'_schema': ["In order to specify an existing codes, please provide the correct registry path prefixed with 'azureml://':\n"]}, {'_schema': ["In order to specify an existing codes, please provide either of the following prefixed with 'azureml:':\n1. The full ARM ID for the resource, e.g.azureml:/subscriptions/<subscription_id>/resourceGroups/<resource_group>/providers/Microsoft.MachineLearningServices/workspaces/<workspace_name>/codes\n2. The short-hand name of the resource registered in the workspace, eg: azureml:<short-hand-name>:<version-if applicable>. For example, version 1 of the environment registered as 'my-env' in the workspace can be referenced as 'azureml:my-env:1'"]}], 'environment': [{'_schema': ['Environment schema data cannot be a string']}, {'_schema': ["In order to specify an existing environments, please provide the correct registry path prefixed with 'azureml://':\n"]}, {'_schema': ["In order to specify an existing environments, please provide either of the following prefixed with 'azureml:':\n1. The full ARM ID for the resource, e.g.azureml:/subscriptions/<subscription_id>/resourceGroups/<resource_group>/providers/Microsoft.MachineLearningServices/workspaces/<workspace_name>/environments\n2. The short-hand name of the resource registered in the workspace, eg: azureml:<short-hand-name>:<version-if applicable>. For example, version 1 of the environment registered as 'my-env' in the workspace can be referenced as 'azureml:my-env:1'"]}]}
#
# The above exception was the direct cause of the following exception:
#
# ValidationError                           Traceback (most recent call last)
# File /workspaces/synth_tab_health_data/az_venv/lib/python3.12/site-packages/azure/ai/ml/entities/_load_functions.py:107, in load_common(cls, source, relative_origin, params_override, **kwargs)
#     106 try:
# --> 107     return _load_common_raising_marshmallow_error(cls, yaml_dict, relative_origin, params_override, **kwargs)
#     108 except ValidationError as e:
#
# File /workspaces/synth_tab_health_data/az_venv/lib/python3.12/site-packages/azure/ai/ml/entities/_load_functions.py:167, in _load_common_raising_marshmallow_error(cls, yaml_dict, relative_origin, params_override, **kwargs)
#     159 def _load_common_raising_marshmallow_error(
#     160     cls: Any,
#     161     yaml_dict: Dict,
#    (...)    165 ) -> Resource:
#     166     # pylint: disable=protected-access
# --> 167     res: Resource = cls._load(data=yaml_dict, yaml_path=relative_origin, params_override=params_override, **kwargs)
#     168     return res
#
# File /workspaces/synth_tab_health_data/az_venv/lib/python3.12/site-packages/azure/ai/ml/entities/_job/job.py:276, in Job._load(cls, data, yaml_path, params_override, **kwargs)
#     275 job_type, type_str = cls._resolve_cls_and_type(data, params_override)
# --> 276 job: Job = job_type._load_from_dict(
#     277     data=data,
#     278     context=context,
#     279     additional_message=f"If you are trying to configure a job that is not of type {type_str}, please specify "
#     280     f"the correct job type in the 'type' property.",
#     281     **kwargs,
#     282 )
#     283 if yaml_path:
#
# File /workspaces/synth_tab_health_data/az_venv/lib/python3.12/site-packages/azure/ai/ml/entities/_builders/command.py:805, in Command._load_from_dict(cls, data, context, additional_message, **kwargs)
#     803 from .command_func import command
# --> 805 loaded_data = load_from_dict(CommandJobSchema, data, context, additional_message, **kwargs)
#     807 # resources a limits properties are flatten in command() function, exact them and set separately
#
# File /workspaces/synth_tab_health_data/az_venv/lib/python3.12/site-packages/azure/ai/ml/entities/_util.py:195, in load_from_dict(schema, data, context, additional_message, **kwargs)
#     194 pretty_error = json.dumps(e.normalized_messages(), indent=2)
# --> 195 raise ValidationError(decorate_validation_error(schema, pretty_error, additional_message)) from e
#
# ValidationError: Validation for CommandJobSchema failed:
#
#  {
#   "code": [
#     {
#       "_schema": [
#         "Can't find directory or file in resolved absolute path: /workspaces/synth_tab_health_data/jobs/experiments."
#       ]
#     },
#     {
#       "_schema": [
#         "Not a valid URL."
#       ]
#     },
#     {
#       "_schema": [
#         "In order to specify a git path, please provide the correct path prefixed with 'git+\n"
#       ]
#     },
#     {
#       "_schema": [
#         "In order to specify an existing codes, please provide the correct registry path prefixed with 'azureml://':\n"
#       ]
#     },
#     {
#       "_schema": [
#         "In order to specify an existing codes, please provide the correct registry path prefixed with 'azureml://':\n"
#       ]
#     },
#     {
#       "_schema": [
#         "In order to specify an existing codes, please provide either of the following prefixed with 'azureml:':\n1. The full ARM ID for the resource, e.g.azureml:/subscriptions/<subscription_id>/resourceGroups/<resource_group>/providers/Microsoft.MachineLearningServices/workspaces/<workspace_name>/codes\n2. The short-hand name of the resource registered in the workspace, eg: azureml:<short-hand-name>:<version-if applicable>. For example, version 1 of the environment registered as 'my-env' in the workspace can be referenced as 'azureml:my-env:1'"
#       ]
#     }
#   ],
#   "environment": [
#     {
#       "_schema": [
#         "Environment schema data cannot be a string"
#       ]
#     },
#     {
#       "_schema": [
#         "In order to specify an existing environments, please provide the correct registry path prefixed with 'azureml://':\n"
#       ]
#     },
#     {
#       "_schema": [
#         "In order to specify an existing environments, please provide either of the following prefixed with 'azureml:':\n1. The full ARM ID for the resource, e.g.azureml:/subscriptions/<subscription_id>/resourceGroups/<resource_group>/providers/Microsoft.MachineLearningServices/workspaces/<workspace_name>/environments\n2. The short-hand name of the resource registered in the workspace, eg: azureml:<short-hand-name>:<version-if applicable>. For example, version 1 of the environment registered as 'my-env' in the workspace can be referenced as 'azureml:my-env:1'"
#       ]
#     }
#   ]
# }
#
#  If you are trying to configure a job that is not of type command, please specify the correct job type in the 'type' property.
#
# Visit this link to refer to the CommandJob schema if needed: https://aka.ms/ml-cli-v2-job-command-yaml-reference.
# The easiest way to author a specification file is using IntelliSense and auto-completion Azure ML VS code extension provides: https://code.visualstudio.com/docs/datascience/azure-machine-learning. To set up: https://learn.microsoft.com/azure/machine-learning/how-to-setup-vs-code
#
# During handling of the above exception, another exception occurred:
#
# ValidationError                           Traceback (most recent call last)
# Cell In[4], line 5
#       2 from azure_ml_client import get_ml_client
#       4 ml_client = get_ml_client()
# ----> 5 job_def = load_job(source="./jobs/evaluate_rtvae.yml")
#       7 job = ml_client.jobs.create_or_update(job_def)
#       8 print(f"Job {job.name} submitted: {job.studio_url}")
#
# File /workspaces/synth_tab_health_data/az_venv/lib/python3.12/site-packages/azure/ai/ml/entities/_load_functions.py:234, in load_job(source, relative_origin, params_override, **kwargs)
#     200 def load_job(
#     201     source: Union[str, PathLike, IO[AnyStr]],
#     202     *,
#    (...)    205     **kwargs: Any,
#     206 ) -> Job:
#     207     """Constructs a Job object from a YAML file.
#     208
#     209     :param source: A path to a local YAML file or an already-open file object containing a job configuration.
#    (...)    232             :caption: Loading a Job from a YAML config file.
#     233     """
# --> 234     return cast(Job, load_common(Job, source, relative_origin, params_override, **kwargs))
#
# File /workspaces/synth_tab_health_data/az_venv/lib/python3.12/site-packages/azure/ai/ml/entities/_load_functions.py:132, in load_common(cls, source, relative_origin, params_override, **kwargs)
#     122         from azure.ai.ml.entities._util import decorate_validation_error
#     124         return ValidationError(
#     125             message=decorate_validation_error(
#     126                 schema=schema.__class__,
#    (...)    129             ),
#     130         )
# --> 132     validation_result.try_raise(error_func=build_error)
#     133 raise e
#
# File /workspaces/synth_tab_health_data/az_venv/lib/python3.12/site-packages/azure/ai/ml/entities/_validation/core.py:253, in MutableValidationResult.try_raise(self, raise_error, error_func)
#     250         def error_func(msg: Union[str, list, dict], _: Any) -> ValidationError:
#     251             return ValidationError(message=msg)
# --> 253     raise error_func(
#     254         self.__repr__(),
#     255         "validation failed on the following fields: " + ", ".join(self.error_messages),
#     256     )
#     257 return self
#
# ValidationError: Validation for CommandSchema failed:
#
#  {
#   "result": "Failed",
#   "errors": [
#     {
#       "message": "Validation for CommandJobSchema failed:\n\n {\n  \"code\": [\n    {\n      \"_schema\": [\n        \"Can't find directory or file in resolved absolute path: /workspaces/synth_tab_health_data/jobs/experiments.\"\n      ]\n    },\n    {\n      \"_schema\": [\n        \"Not a valid URL.\"\n      ]\n    },\n    {\n      \"_schema\": [\n        \"In order to specify a git path, please provide the correct path prefixed with 'git+\\n\"\n      ]\n    },\n    {\n      \"_schema\": [\n        \"In order to specify an existing codes, please provide the correct registry path prefixed with 'azureml://':\\n\"\n      ]\n    },\n    {\n      \"_schema\": [\n        \"In order to specify an existing codes, please provide the correct registry path prefixed with 'azureml://':\\n\"\n      ]\n    },\n    {\n      \"_schema\": [\n        \"In order to specify an existing codes, please provide either of the following prefixed with 'azureml:':\\n1. The full ARM ID for the resource, e.g.azureml:/subscriptions/<subscription_id>/resourceGroups/<resource_group>/providers/Microsoft.MachineLearningServices/workspaces/<workspace_name>/codes\\n2. The short-hand name of the resource registered in the workspace, eg: azureml:<short-hand-name>:<version-if applicable>. For example, version 1 of the environment registered as 'my-env' in the workspace can be referenced as 'azureml:my-env:1'\"\n      ]\n    }\n  ],\n  \"environment\": [\n    {\n      \"_schema\": [\n        \"Environment schema data cannot be a string\"\n      ]\n    },\n    {\n      \"_schema\": [\n        \"In order to specify an existing environments, please provide the correct registry path prefixed with 'azureml://':\\n\"\n      ]\n    },\n    {\n      \"_schema\": [\n        \"In order to specify an existing environments, please provide either of the following prefixed with 'azureml:':\\n1. The full ARM ID for the resource, e.g.azureml:/subscriptions/<subscription_id>/resourceGroups/<resource_group>/providers/Microsoft.MachineLearningServices/workspaces/<workspace_name>/environments\\n2. The short-hand name of the resource registered in the workspace, eg: azureml:<short-hand-name>:<version-if applicable>. For example, version 1 of the environment registered as 'my-env' in the workspace can be referenced as 'azureml:my-env:1'\"\n      ]\n    }\n  ]\n} \n\n If you are trying to configure a job that is not of type command, please specify the correct job type in the 'type' property.\n\nVisit this link to refer to the CommandJob schema if needed: https://aka.ms/ml-cli-v2-job-command-yaml-reference.\nThe easiest way to author a specification file is using IntelliSense and auto-completion Azure ML VS code extension provides: https://code.visualstudio.com/docs/datascience/azure-machine-learning. To set up: https://learn.microsoft.com/azure/machine-learning/how-to-setup-vs-code",
#       "path": "*",
#       "value": null,
#       "location": "./jobs/evaluate_rtvae.yml"
#     }
#   ]
# }
#
#  If you are trying to configure an entity that is not of type command, please specify the correct type in the 'type' property.
# The easiest way to author a specification file is using IntelliSense and auto-completion Azure ML VS code extension provides: https://code.visualstudio.com/docs/datascience/azure-machine-learning. To set up: https://learn.microsoft.com/azure/machine-learning/how-to-setup-vs-code
