# %% [markdown]
# # Running Evaluations

# %%
# %pip install azure-ai-ml azure-identity python-dotenv

# %% [markdown]
# Prepare Azure ML client:

# %%
from azureml.azure_ml_client import get_ml_client

ml_client = get_ml_client()
# Out:
# Overriding of current MeterProvider is not allowed
# Overriding of current TracerProvider is not allowed
# Overriding of current LoggerProvider is not allowed
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented

# %%
from azure.ai.ml import load_job

# %% [markdown]
# ### ADS-GAN evaluation job

# %%
dataset_names = [
    'alzheimers',
    'breast_cancer',
    'coronary_artery',
    'diabetes',
    'gallstone'
]

# %%
for name in dataset_names:
    job_def = load_job(source=f"./jobs/adsgan/adsgan_{name}.yml")
    job = ml_client.jobs.create_or_update(job_def)
    print(f"Job {job.name} submitted: {job.studio_url}")
# Out:
# pathOnCompute is not a known attribute of class <class 'azure.ai.ml._restclient.v2023_04_01_preview.models._models_py3.UriFileJobOutput'> and will be ignored
# Job eager_kettle_l3bwv354w5 submitted: https://ml.azure.com/runs/eager_kettle_l3bwv354w5?wsid=/subscriptions/c765ad7a-43a2-4f2b-b4e6-4f48de899bcb/resourcegroups/rg-qcp-omics-dev-neu/workspaces/synthtabhealthdata&tid=7e6887cf-84b7-426e-b0cd-bd87a3f7977d
# pathOnCompute is not a known attribute of class <class 'azure.ai.ml._restclient.v2023_04_01_preview.models._models_py3.UriFileJobOutput'> and will be ignored
# Job olive_wall_j6dt7m3lw3 submitted: https://ml.azure.com/runs/olive_wall_j6dt7m3lw3?wsid=/subscriptions/c765ad7a-43a2-4f2b-b4e6-4f48de899bcb/resourcegroups/rg-qcp-omics-dev-neu/workspaces/synthtabhealthdata&tid=7e6887cf-84b7-426e-b0cd-bd87a3f7977d
# pathOnCompute is not a known attribute of class <class 'azure.ai.ml._restclient.v2023_04_01_preview.models._models_py3.UriFileJobOutput'> and will be ignored
# ...

# %%
# resubmit
job_def = load_job(source="./jobs/adsgan/adsgan_breast_cancer.yml")
job = ml_client.jobs.create_or_update(job_def)
print(f"Job {job.name} submitted: {job.studio_url}")
# Out:
# pathOnCompute is not a known attribute of class <class 'azure.ai.ml._restclient.v2023_04_01_preview.models._models_py3.UriFileJobOutput'> and will be ignored
# Job dreamy_book_8hr14ljm4p submitted: https://ml.azure.com/runs/dreamy_book_8hr14ljm4p?wsid=/subscriptions/c765ad7a-43a2-4f2b-b4e6-4f48de899bcb/resourcegroups/rg-qcp-omics-dev-neu/workspaces/synthtabhealthdata&tid=7e6887cf-84b7-426e-b0cd-bd87a3f7977d

# %% [markdown]
# ### CTGAN evaluation job

# %%
for name in dataset_names:
    job_def = load_job(source=f"./jobs/ctgan/ctgan_{name}.yml")
    job = ml_client.jobs.create_or_update(job_def)
    print(f"Job {job.name} submitted: {job.studio_url}")
# Out:
# pathOnCompute is not a known attribute of class <class 'azure.ai.ml._restclient.v2023_04_01_preview.models._models_py3.UriFileJobOutput'> and will be ignored
# Job joyful_napa_b4x2npwnc7 submitted: https://ml.azure.com/runs/joyful_napa_b4x2npwnc7?wsid=/subscriptions/c765ad7a-43a2-4f2b-b4e6-4f48de899bcb/resourcegroups/rg-qcp-omics-dev-neu/workspaces/synthtabhealthdata&tid=7e6887cf-84b7-426e-b0cd-bd87a3f7977d
# pathOnCompute is not a known attribute of class <class 'azure.ai.ml._restclient.v2023_04_01_preview.models._models_py3.UriFileJobOutput'> and will be ignored
# Job nice_candle_1vmqmzqqlm submitted: https://ml.azure.com/runs/nice_candle_1vmqmzqqlm?wsid=/subscriptions/c765ad7a-43a2-4f2b-b4e6-4f48de899bcb/resourcegroups/rg-qcp-omics-dev-neu/workspaces/synthtabhealthdata&tid=7e6887cf-84b7-426e-b0cd-bd87a3f7977d
# pathOnCompute is not a known attribute of class <class 'azure.ai.ml._restclient.v2023_04_01_preview.models._models_py3.UriFileJobOutput'> and will be ignored
# ...

# %%
job_def = load_job(source="./jobs/evaluate_ctgan.yml")

job = ml_client.jobs.create_or_update(job_def)
print(f"Job {job.name} submitted: {job.studio_url}")

# %% [markdown]
# ### PATEGAN evalution job

# %%
for name in dataset_names:
    job_def = load_job(source=f"./jobs/pategan/pategan_{name}.yml")
    job = ml_client.jobs.create_or_update(job_def)
    print(f"Job {job.name} submitted: {job.studio_url}")
# Out:
# pathOnCompute is not a known attribute of class <class 'azure.ai.ml._restclient.v2023_04_01_preview.models._models_py3.UriFileJobOutput'> and will be ignored
# Job great_room_k7svxsz1y1 submitted: https://ml.azure.com/runs/great_room_k7svxsz1y1?wsid=/subscriptions/c765ad7a-43a2-4f2b-b4e6-4f48de899bcb/resourcegroups/rg-qcp-omics-dev-neu/workspaces/synthtabhealthdata&tid=7e6887cf-84b7-426e-b0cd-bd87a3f7977d
# pathOnCompute is not a known attribute of class <class 'azure.ai.ml._restclient.v2023_04_01_preview.models._models_py3.UriFileJobOutput'> and will be ignored
# Job wheat_corn_qh6t8ddty0 submitted: https://ml.azure.com/runs/wheat_corn_qh6t8ddty0?wsid=/subscriptions/c765ad7a-43a2-4f2b-b4e6-4f48de899bcb/resourcegroups/rg-qcp-omics-dev-neu/workspaces/synthtabhealthdata&tid=7e6887cf-84b7-426e-b0cd-bd87a3f7977d
# pathOnCompute is not a known attribute of class <class 'azure.ai.ml._restclient.v2023_04_01_preview.models._models_py3.UriFileJobOutput'> and will be ignored
# ...

# %% [markdown]
# ### RTVAE evaluation job

# %%
job_def = load_job(source="./jobs/evaluate_rtvae.yml")

job = ml_client.jobs.create_or_update(job_def)
print(f"Job {job.name} submitted: {job.studio_url}")

# %% [markdown]
# ### Normalizing Flows evaluation job

# %%
job_def = load_job(source="./jobs/evaluate_nflow.yml")

job = ml_client.jobs.create_or_update(job_def)
print(f"Job {job.name} submitted: {job.studio_url}")

# %% [markdown]
# ### Bayesian Network evaluation job

# %%
job_def = load_job(source="./jobs/evaluate_bayesian_network.yml")

job = ml_client.jobs.create_or_update(job_def)
print(f"Job {job.name} submitted: {job.studio_url}")

# %% [markdown]
# ### TabDDPM evaluation job

# %%
job_def = load_job(source="./jobs/evaluate_ddpm.yml")

job = ml_client.jobs.create_or_update(job_def)
print(f"Job {job.name} submitted: {job.studio_url}")
