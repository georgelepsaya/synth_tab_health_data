# %% [markdown]
# # Running Evaluations

# %% [markdown]
# Prepare Azure ML client:

# %%
from azureml.azure_ml_client import get_ml_client

ml_client = get_ml_client()
# Out:
# Overriding of current TracerProvider is not allowed
# Overriding of current LoggerProvider is not allowed
# Overriding of current MeterProvider is not allowed
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented

# %% [markdown]
# ### CTGAN Evaluation job

# %%
from azure.ai.ml import load_job

job_def = load_job(source="./jobs/evaluate_ctgan.yml")

job = ml_client.jobs.create_or_update(job_def)
print(f"Job {job.name} submitted: {job.studio_url}")
# Out:
# Uploading synthcity (0.0 MBs): 100%|██████████| 1883/1883 [00:00<00:00, 90863.72it/s]
#
#
# pathOnCompute is not a known attribute of class <class 'azure.ai.ml._restclient.v2023_04_01_preview.models._models_py3.UriFileJobOutput'> and will be ignored
# Job frank_yacht_nf5tjzm5st submitted: https://ml.azure.com/runs/frank_yacht_nf5tjzm5st?wsid=/subscriptions/c765ad7a-43a2-4f2b-b4e6-4f48de899bcb/resourcegroups/rg-qcp-omics-dev-neu/workspaces/synthtabhealthdata&tid=7e6887cf-84b7-426e-b0cd-bd87a3f7977d

# %% [markdown]
# ### RTVAE Evaluation job

# %%
job_def = load_job(source="./jobs/evaluate_rtvae.yml")

job = ml_client.jobs.create_or_update(job_def)
print(f"Job {job.name} submitted: {job.studio_url}")
# Out:
# pathOnCompute is not a known attribute of class <class 'azure.ai.ml._restclient.v2023_04_01_preview.models._models_py3.UriFileJobOutput'> and will be ignored
# Job salmon_tray_65nxwmljxt submitted: https://ml.azure.com/runs/salmon_tray_65nxwmljxt?wsid=/subscriptions/c765ad7a-43a2-4f2b-b4e6-4f48de899bcb/resourcegroups/rg-qcp-omics-dev-neu/workspaces/synthtabhealthdata&tid=7e6887cf-84b7-426e-b0cd-bd87a3f7977d
